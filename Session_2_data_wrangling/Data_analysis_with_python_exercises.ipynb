# %% [markdown]
# ## 🎮 Business Case: Growing Entero's New Game Globba
#
#
# **Performance Marketing**
#
# Following your earlier analysis of the Finnish gaming company Enterio, the team has now completed development on its latest title:
#
# **Globba** — a casual Match-3 game where players build and care for a farm while completing levels !!!
#
# **📈 From Development to Growth**
#
#
# With the game built and tested, Entero's next challenge is to grow the player base through performance marketing. This means investing in paid advertising campaigns across multiple digital platforms to acquire new users efficiently.
#
# To make informed decisions, your team has been given a dataset containing real performance data from recent marketing campaigns for different game types — including Match 3, RPG, and Shooter.
#
# **🧪 Your Task**
#
# As a Business Analyst at Entero. Your job is to analyze the dataset and be able to answer, at the end of the exercise, key business questions such as:
#
# - Which channels are most effective for acquiring players?
#
# - Where does Match 3 perform best?
#
# - Which platforms have higher acquisition costs?
#
# Are there specific trends based on game type or date?
#
# But let's go step by step

# %%
from google.colab import drive
drive.mount('/content/drive')

path_image_entero = '/content/drive/MyDrive/Session_2_data_wrangling/images/entero_globba_all.png'
from IPython.display import Image, display
display(Image(filename=path_image_entero))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #  1.&nbsp; Set up

# %% [markdown]
# Let's import pandas, numpy and matplotlib libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #  2.&nbsp;  Read the dataset and basic operations

# %% [markdown]
# 2.1) Read the performance_marketing_2025.xlsx from the folder dataset using `pd.read_excel()`

# %%
#Your solution

# %% [markdown]
# 2.2) What is the shape of the dataset (number of rows and columns)?

# %%
#Your solution

# %% [markdown]
# 2.3) What are the column names and their data types?

# %%
#Your solution

# %% [markdown]
# 2.4) Show the first 10 rows of the dataset

# %%
#Your solution

# %% [markdown]
#  2.5) Show the last 7 rows of the dataset

# %%
#Your solution

# %% [markdown]
# 2.6) Show the first 5 rows for the column installs

# %%
#Your solution

# %% [markdown]
# 2.7) Select 10th row

# %%
#Your solution

# %% [markdown]
# 2.8) Use .describe() to get basic statics information for each numeric variable

# %%
#Your solution

# %% [markdown]
# # 3.- Rows and columns manipulations

# %% [markdown]
# 3.1) Filter rows where Channel is 'Instagram'

# %%
#Your solution

# %% [markdown]
# 3.2) Filter rows where:
#
# - Game type is Match 3
#
# - Channel is TikTok

# %%
#Your solution

# %% [markdown]
# 3.3) Rename column `Game_Type`to `Game_mode` . Set the parameter `inplace` of .`rename()` to False since we do not want the name to change permanently

# %%
#Your solution

# %% [markdown]
# 3.4) Create a new column for Cost per Install (CPI) where
#
#  $$CPI = \frac{\text{Acquisition_Cost}}{\text{installs}}$$
#
# name the resulting column as CPI

# %%
#Your solution

# %% [markdown]
# 3.5) (Bonus !!!) Create a new column called installs_bucket. The column can take 3 values depending on the total number of installs such as:
#
# - If installs are <100 then 'Low'
# - If installs are >=100 and <=250 then 'Medium'
# - If install are >250 then 'High
#
# Hint: Use apply or map. Gemini might even suggest pd.cut

# %%
#Your solution

# %% [markdown]
# #  4.&nbsp; Aggregations

# %% [markdown]
# 4.1) What is the total cost of acquisition per channel? Basically how much money has been spend per channel? Use `.groupby()`

# %%
#Your solution

# %% [markdown]
# 4.2) Which day had the highest installs? (Across all channels and game_type) .Use `.groupby()` and `sort_values()`

# %%
#Your solution

# %% [markdown]
# 4.3) What is the total number of installs by game type per day? (Suggestion to group by Date and Game Type) . Can you plot it in a line-chart?

# %%
#Your solution

# %% [markdown]
# 4.5) Which is the average number of installs per Game type and Channel? (Group by Game Type and Channel) What can you say regarding Match-3 games and possible channel to invest? (Suggestion: You can either use `.groupby()` or `pivot_table()`)

# %%
#Your solution

# %% [markdown]
# 4.6) From the question above it seems for Match 3, Facebook and Tik Tok are interesting channel options to invest. But let's add the layer of acquisition cost. Create a pivot table with Game Type in the index, Channel in column and compute the average CPI. What is telling us? (Suggestion: You can either use `.groupby()` or `pivot_table()`)

# %%
#Your solution
