# %% [markdown]
# ## Exam Python section

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Understanding the dataset

# %% [markdown]
# 1.0) Import the main data analysis libraries such as pandas, numpy, matplotlib.pylot and seaborn

# %%
# Your solution
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1.1) Read the dataset named `messaging_apps.xlsx` from the Datasets folder using `pd.read_excel()`, and store it in a variable named df.

# %%
# Your solution
df = pd.read_excel('/content/drive/MyDrive/Python_for_ESADE/Exams/Retake_Exam/Datasets/messaging_apps.xlsx')

# %% [markdown]
# 1.2) Display the first 5 rows of the dataset

# %%
# Your solution
df.head()
# Out:
#          Date Messaging_App  Region Type_of_Message  Number_of_messages  Cost  \
# 0  2025-06-01      iMessage      US    Text message               14301  0.29
# 1  2025-06-01      iMessage      US          Images                 830  0.05
# 2  2025-06-01      iMessage      US          Videos                 849  0.07
# 3  2025-06-01      iMessage      US   Voice message                 929  0.04
# 4  2025-06-01      iMessage  France    Text message                3878  0.08
#
#    Revenue
# 0    14.30
# 1     0.83
# 2     0.85
# 3     0.93
# 4     3.88

# %% [markdown]
# 1.3) What is the shape of the dataset (number of rows and columns)?

# %%
# Your solution
df.shape
# Out:
# (980, 7)

# %% [markdown]
# 1.4) What are the column names and their data types? Use either `dtypes` or `.info()` or both

# %%
# Your solution
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                980 non-null    object
#  1   Messaging_App       980 non-null    object
#  2   Region              980 non-null    object
#  3   Type_of_Message     980 non-null    object
#  4   Number_of_messages  980 non-null    int64
#  5   Cost                980 non-null    float64
#  6   Revenue             980 non-null    float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 53.7+ KB

# %% [markdown]
# 1.5)Filter the rows such as `Messaging_App` is `Whatsapp`

# %%
# Your solution
df[df['Messaging_App'] == 'Whatsapp']
# Out:
#            Date Messaging_App  Region Type_of_Message  Number_of_messages  \
# 60   2025-06-01      Whatsapp      US    Text message               22900
# 61   2025-06-01      Whatsapp      US          Images                1265
# 62   2025-06-01      Whatsapp      US          Videos                1370
# 63   2025-06-01      Whatsapp      US   Voice message                1401
# 64   2025-06-01      Whatsapp  France    Text message               11335
# ..          ...           ...     ...             ...                 ...
# 915  2025-06-07      Whatsapp   India   Voice message                1370
# 916  2025-06-07      Whatsapp   Japan    Text message               25080
# 917  2025-06-07      Whatsapp   Japan          Images                1483
# 918  2025-06-07      Whatsapp   Japan          Videos                1523
# 919  2025-06-07      Whatsapp   Japan   Voice message                1465
#
#      Cost  Revenue
# 60   0.46     6.87
# 61   0.08     0.38
# ...

# %% [markdown]
# 1.6) Filter the rows such as `Messaging_App` is `Whatsapp` and Region is `Japan`

# %%
# Your solution
df[(df['Messaging_App'] == 'Whatsapp') & (df['Region'] == 'Japan')]
# Out:
#            Date Messaging_App Region Type_of_Message  Number_of_messages  \
# 76   2025-06-01      Whatsapp  Japan    Text message               18912
# 77   2025-06-01      Whatsapp  Japan          Images                1159
# 78   2025-06-01      Whatsapp  Japan          Videos                1114
# 79   2025-06-01      Whatsapp  Japan   Voice message                1142
# 216  2025-06-02      Whatsapp  Japan    Text message               17071
# 217  2025-06-02      Whatsapp  Japan          Images                1002
# 218  2025-06-02      Whatsapp  Japan          Videos                 947
# 219  2025-06-02      Whatsapp  Japan   Voice message                1036
# 356  2025-06-03      Whatsapp  Japan    Text message               23607
# 357  2025-06-03      Whatsapp  Japan          Images                1481
# 358  2025-06-03      Whatsapp  Japan          Videos                1433
# 359  2025-06-03      Whatsapp  Japan   Voice message                1432
# ...

# %% [markdown]
# 1.7) Filter the rows such as:
#
#   - `Messaging_App` is `Whatsapp`
#
#   - `Region` is `Japan`
#
#   - `Type_of_Message` is `Images`

# %%
# Your solution
df[(df['Messaging_App'] == 'Whatsapp') & (df['Region'] == 'Japan') & (df['Type_of_Message'] == 'Images')]
# Out:
#            Date Messaging_App Region Type_of_Message  Number_of_messages  \
# 77   2025-06-01      Whatsapp  Japan          Images                1159
# 217  2025-06-02      Whatsapp  Japan          Images                1002
# 357  2025-06-03      Whatsapp  Japan          Images                1481
# 497  2025-06-04      Whatsapp  Japan          Images                1254
# 637  2025-06-05      Whatsapp  Japan          Images                1168
# 777  2025-06-06      Whatsapp  Japan          Images                1369
# 917  2025-06-07      Whatsapp  Japan          Images                1483
#
#      Cost  Revenue
# 77   0.07     0.35
# 217  0.06     0.30
# 357  0.09     0.44
# 497  0.08     0.38
# 637  0.07     0.35
# 777  0.08     0.41
# 917  0.09     0.44

# %% [markdown]
# 1.8) What was the total `Revenue` in `US`, on `2025-06-01` for `Videos` (`Type_of_Message`) across all `Messaging_App`?

# %%
# Your solution
df[(df['Region'] == 'US') & (df['Date'] == '2025-06-01') & (df['Type_of_Message'] == 'Videos')]['Revenue'].sum()
# Out:
# np.float64(3.13)

# %% [markdown]
# ### Aggregations

# %% [markdown]
# 2.1) Create a pivot table to count how many `Number_of_messages` were sent in each `Region`. Store the results in a dataframe called `df_region`
#
# 💡 *Hint: Recall the syntax for `pd.pivot_table(df,index=,values=,aggfunc=)`

# %%
df_region = pd.pivot_table(df,index='Region',values='Number_of_messages',aggfunc='sum')
df_region
# Out:
#         Number_of_messages
# Region
# China               636709
# France              284660
# India               341095
# Japan               440266
# US                  425995

# %% [markdown]
# 2.2) In 2.1) The dataframe `df_region` should have the absolute frequency of `Number_of_messages` per `Region`. Let's add a column with the **relative frequency**.
#
# For the dataframe `df_region` perform two computations:
#
# - **2.2.1)** Calculate the **total number of messages** across all countries by summing the values in the player count column.
# 💡 *Hint: Use the `.sum()` method on the appropriate column.*
#
# - **2.2.2)** Using the total from the previous step, add a new column to `df_region` that contains the **relative frequency** (as a percentage) of messages shared in each country.
# 💡 *Hint: Divide the number of messages count column by the total number of messages and multiply by 100.

# %%
df_region['relative_frequency'] = (df_region['Number_of_messages']/df_region['Number_of_messages'].sum())*100
df_region
# Out:
#         Number_of_messages  relative_frequency
# Region
# China               636709           29.910345
# France              284660           13.372324
# India               341095           16.023441
# Japan               440266           20.682145
# US                  425995           20.011744

# %% [markdown]
# 2.3) Plot in an appropiate chart (either bar chart or pie chart) the relative proportion that each Region represents from exercise 2.2) . Either use matplotlib or seaborn (0.4 points)

# %%
# Pie chart
plt.figure()
plt.pie(df_region['relative_frequency'],labels=df_region.index)
plt.show()

# %%
#bar chart
plt.figure()
sns.barplot(x=df_region.index,y=df_region['relative_frequency'])
plt.show()

# %%
# Bar chart plt
plt.figure()
plt.bar(df_region.index,df_region['relative_frequency'])
plt.show()
#

# %% [markdown]
# 2.4) Explore the relationship between Number_of_messages and Revenue.
# Create a scatter plot to visualize the relationship between **Number_of_messages** and **Revenue** using the `df` DataFrame.
#
# 💡 Hint: Use plt.scatter() from matplotlib.pyplot. Don't forget to add labels to the axes using plt.xlabel() and plt.ylabel() to make the chart easier to interpret.

# %%
plt.scatter(df['Number_of_messages'],df['Revenue'])
plt.xlabel('Messages')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# 2.5) Does the previous plot suggest a positive relationship between Number_of_messages and revenue?
#
# To prove it analytically, compute the correlation coefficient between the variables Number_of_messages and revenue.
#
# 💡 Hint: You can use either the .corr() method in pandas or np.corrcoef() from NumPy.

# %%
df[['Number_of_messages','Revenue']].corr()
# Out:
#                     Number_of_messages   Revenue
# Number_of_messages            1.000000  0.879945
# Revenue                       0.879945  1.000000

# %%
df['Number_of_messages'].corr(df['Revenue'])
# Out:
# np.float64(0.8799448494064682)

# %%
df.head()
# Out:
#          Date Messaging_App  Region Type_of_Message  Number_of_messages  Cost  \
# 0  2025-06-01      iMessage      US    Text message               14301  0.29
# 1  2025-06-01      iMessage      US          Images                 830  0.05
# 2  2025-06-01      iMessage      US          Videos                 849  0.07
# 3  2025-06-01      iMessage      US   Voice message                 929  0.04
# 4  2025-06-01      iMessage  France    Text message                3878  0.08
#
#    Revenue
# 0    14.30
# 1     0.83
# 2     0.85
# 3     0.93
# 4     3.88

# %% [markdown]
# **Regional Usage Analysis – Most Used Messaging_App**
#
# 2.6) Let’s perform a geographic breakdown to better understand usage patterns across regions.
#
# Your task is to identify which `Messaging_App` is the most used in terms of total number of messages sent in selected regions.
#
# Create a pivot table showing the total `Number_of_messages` per combination of `Region` and `Messaging_App`.
#
# Based on this table, answer the following:
#
# - Which `Messaging_App` has the highest total number of messages in the `US`?
#
# - Which `Messaging_App` has the highest total number of messages in `China`?

# %%
pd.pivot_table(df,index='Messaging_App',columns='Region',values='Number_of_messages',aggfunc='sum')
# Out:
# Region               China  France   India   Japan      US
# Messaging_App
# Facebook Messenger    5015   37411   40101   32061   45928
# LINE                  4657   41925   39074  119726   33018
# Snapchat              4870   37000   26377   40059   39726
# Telegram              4902   38549   31609   37055   35906
# WeChat              607147    1733    1640    2036    2250
# Whatsapp              4688   86039  169404  176344  165009
# iMessage              5430   42003   32890   32985  104158

# %%
pd.pivot_table(df,index='Messaging_App',columns='Region',values='Number_of_messages',aggfunc='sum')[['China']].max()
# Out:
# Region
# China    607147
# dtype: int64

# %% [markdown]
# In Asia is WeChat

# %%
pd.pivot_table(df,index='Messaging_App',columns='Region',values='Number_of_messages',aggfunc='sum')[['US']].max()
# Out:
# Region
# US    165009
# dtype: int64

# %% [markdown]
# **Cost Efficiency Analysis – Which Type of Message is most costly?**
#
# 2.7) Let's identify which Type of Message is the most costly 💵, based on the unitary total cost per message sent across the dataset. Thus for each `Type of Message` let's compute:
#
# $$\text{Cost_per_message} = \frac{\text{Sum of total cost}}{\text{Sum of Number of Messages sent}} $$
#
# - Step 1: Create a pivot table capturing the sum of total `Number_of_messages` per `Type of Message`. Store the information in a variable called `df_messages_total`.
#
#     💡 *Hint: Recall the syntax for `pd.pivot_table(df,index=,values=,aggfunc=)`
#
# - Step 2: Create a second pivot table capturing the sum of cost (`Cost`) per `Type of Message`. Store the information in a variable called `df_cost`.
#
#     💡 *Hint: Recall the syntax for `pd.pivot_table(df,index=,values=,aggfunc=)`
#
# - Step 3: Divide the total cost by the total number of messages for each type of message to calculate the average cost per message. To do so execute
#
#   ```python
#   df_cost['Cost'] / df_queries_total['Number_of_messages']
#   ```
#
# Based on this analysis, which Type of message is the most expensive to share/sent?

# %%
df_messages_total = pd.pivot_table(df,index='Type_of_Message',values='Number_of_messages',aggfunc='sum')
df_messages_total
# Out:
#                  Number_of_messages
# Type_of_Message
# Images                       219663
# Text message                1581667
# Videos                       213184
# Voice message                114211

# %%
df_cost = pd.pivot_table(df,index='Type_of_Message',values='Cost',aggfunc='sum')
df_cost
# Out:
#                   Cost
# Type_of_Message
# Images           13.00
# Text message     31.59
# Videos           16.97
# Voice message     4.46

# %%
df_queries_total = pd.pivot_table(df,index='Type_of_Message',values='Number_of_messages',aggfunc='sum')
df_cost = pd.pivot_table(df,index='Type_of_Message',values='Cost',aggfunc='sum')
df_cost['Cost'] / df_queries_total['Number_of_messages']
# Out:
# Type_of_Message
# Images           0.000059
# Text message     0.000020
# Videos           0.000080
# Voice message    0.000039
# dtype: float64

# %% [markdown]
# 2.8) Create a pivot table to compute the total `Number_of_messages` per day (`Date`) variable. Plot the resulting table in line chart. Use `plt.plot`

# %%
df.head()
# Out:
#          Date Messaging_App  Region Type_of_Message  Number_of_messages  Cost  \
# 0  2025-06-01      iMessage      US    Text message               14301  0.29
# 1  2025-06-01      iMessage      US          Images                 830  0.05
# 2  2025-06-01      iMessage      US          Videos                 849  0.07
# 3  2025-06-01      iMessage      US   Voice message                 929  0.04
# 4  2025-06-01      iMessage  France    Text message                3878  0.08
#
#    Revenue
# 0    14.30
# 1     0.83
# 2     0.85
# 3     0.93
# 4     3.88

# %%
df_ts = pd.pivot_table(df,index='Date',values='Number_of_messages',aggfunc='sum')
df_ts
# Out:
#             Number_of_messages
# Date
# 2025-06-01              312963
# 2025-06-02              285305
# 2025-06-03              299154
# 2025-06-04              302263
# 2025-06-05              312603
# 2025-06-06              293047
# 2025-06-07              323390

# %%
plt.plot(df_ts.index,df_ts['Number_of_messages'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Quiz

# %%
df['Date'].max()
# Out:
# '2025-06-07'

# %%
counter=5
while counter>1:
  if counter<4:
    print(f"Counter {counter}--> Whoof")
  counter-=1
# Out:
# Counter 3--> Whoof
# Counter 2--> Whoof

# %%
1 a
2 c
3 d
4 d
5 a

# %%
df
# Out:
#            Date Messaging_App  Region Type_of_Message  Number_of_messages  \
# 0    2025-06-01      iMessage      US    Text message               14301
# 1    2025-06-01      iMessage      US          Images                 830
# 2    2025-06-01      iMessage      US          Videos                 849
# 3    2025-06-01      iMessage      US   Voice message                 929
# 4    2025-06-01      iMessage  France    Text message                3878
# ..          ...           ...     ...             ...                 ...
# 975  2025-06-07          LINE   India   Voice message                 384
# 976  2025-06-07          LINE   Japan    Text message               15589
# 977  2025-06-07          LINE   Japan          Images                 886
# 978  2025-06-07          LINE   Japan          Videos                 906
# 979  2025-06-07          LINE   Japan   Voice message                 912
#
#      Cost  Revenue
# 0    0.29    14.30
# 1    0.05     0.83
# ...

# %%
# Select rows in defion such as region is US, AI_assistant is Grok, type of_question is Business
df[(df['Region'] == 'US') & (df['Messaging_App'] == 'LINE') & (df['Type_of_Message'] == 'Voice message')]
# Out:
#            Date Messaging_App Region Type_of_Message  Number_of_messages  \
# 123  2025-06-01          LINE     US   Voice message                 331
# 263  2025-06-02          LINE     US   Voice message                 204
# 403  2025-06-03          LINE     US   Voice message                 255
# 543  2025-06-04          LINE     US   Voice message                 141
# 683  2025-06-05          LINE     US   Voice message                 245
# 823  2025-06-06          LINE     US   Voice message                 305
# 963  2025-06-07          LINE     US   Voice message                 215
#
#      Cost  Revenue
# 123  0.01     0.33
# 263  0.01     0.20
# 403  0.01     0.26
# 543  0.01     0.14
# 683  0.01     0.24
# 823  0.01     0.30
# 963  0.01     0.22

# %%
# prompt: Select region Us, Line app and voice message for type

df[(df['Region'] == 'US') & (df['Messaging_App'] == 'LINE') & (df['Type_of_Message'] == 'Voice message')]
# Out:
#            Date Messaging_App Region Type_of_Message  Number_of_messages  \
# 123  2025-06-01          LINE     US   Voice message                 331
# 263  2025-06-02          LINE     US   Voice message                 204
# 403  2025-06-03          LINE     US   Voice message                 255
# 543  2025-06-04          LINE     US   Voice message                 141
# 683  2025-06-05          LINE     US   Voice message                 245
# 823  2025-06-06          LINE     US   Voice message                 305
# 963  2025-06-07          LINE     US   Voice message                 215
#
#      Cost  Revenue
# 123  0.01     0.33
# 263  0.01     0.20
# 403  0.01     0.26
# 543  0.01     0.14
# 683  0.01     0.24
# 823  0.01     0.30
# 963  0.01     0.22

# %%
def output_animal(animal, number):
  if number>4 and number/2>2:
    if len(animal)==3:
      return "Short name !!!"
    elif len(animal)>4 and len(animal)<=8:
      return "Medium name !!!"
    elif len(animal)>=9:
      return 'Large name'
  elif number>4 and number/2<=2:
    if len(animal)==3:
      return "Short name !!!"
    elif len(animal)>4 and len(animal)<=8:
      return "Medium name !!!"
    elif len(animal)>=9:
      return 'Large name'
  else:
    return 'Nothing applies'

output_animal('impala', 4)
# Out:
# 'Nothing applies'
